# %% [markdown]
# # Managing RDF data in python
#
#
#  1. Introduction to RDFlib
#  2. Querying RDF data
#  3. Creating RDF triples
#  4. Saving and storing RDF data

# %%
# all imports
# if run in colab run:
#!pip install rdflib

import pprint
import rdflib
from rdflib import URIRef, Literal, Namespace
from rdflib.namespace import XSD, RDFS, DCTERMS
from rdflib import Literal
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting rdflib
#   Downloading rdflib-6.1.1-py3-none-any.whl (482 kB)
#      |████████████████████████████████| 482 kB 13.7 MB/s
# Requirement already satisfied: setuptools in /usr/local/lib/python3.7/dist-packages (from rdflib) (57.4.0)
# Collecting isodate
#   Downloading isodate-0.6.1-py2.py3-none-any.whl (41 kB)
#      |████████████████████████████████| 41 kB 793 kB/s
# Requirement already satisfied: importlib-metadata in /usr/local/lib/python3.7/dist-packages (from rdflib) (4.11.4)
# Requirement already satisfied: pyparsing in /usr/local/lib/python3.7/dist-packages (from rdflib) (3.0.9)
# Requirement already satisfied: typing-extensions>=3.6.4 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib) (4.1.1)
# Requirement already satisfied: zipp>=0.5 in /usr/local/lib/python3.7/dist-packages (from importlib-metadata->rdflib) (3.8.0)
# Requirement already satisfied: six in /usr/local/lib/python3.7/dist-packages (from isodate->rdflib) (1.15.0)
# Installing collected packages: isodate, rdflib
# Successfully installed isodate-0.6.1 rdflib-6.1.1

# %% [markdown]
# ## 1. Introduction to RDFlib
#
# RDFlib is a python library for managing RDF data in Python in local servers or server-side web applications. It allows one to:
#
#  * parse RDF data stored in files (either local or online) with several syntaxes
#  * manipulate RDF data by creating a in-memory graph
#  * query RDF data by means of SPARQL queries and other built-in constructs
#  * serialize and store RDF data in files.
#
# ### How does it work?
#
# Basically, a graph is treated as an unordered list of tuples. Each tuple has three elements, namely two/three URIs corresponding to subject, predicate, and object.

# %%
subj1 = '<http://example.org/robert_capa>'
subj2 = '<http://example.org/gerda_taro>'
pred1 = '<http://example.org/knows>'
pred2 = '<http://example.org/hasSpouse>'
obj1 = '<http://example.org/henri_cartier_bresson>'

# the basic behaviour in RDFlib
example_graph = [
    (subj1, pred1, obj1),
    (subj2, pred2, subj1)
]

# %% [markdown]
# NB. An object can be either a URI or a literal (e.g. a string, a date, an integer and so on). Have a look at the [RDFlib supported terms](https://rdflib.readthedocs.io/en/stable/rdf_terms.html)

# %% [markdown]
# ### Parse RDF data from string
#
# If the data are stored in a file or a **string**, this must be parsed and the data transformed in an in-memory graph (i.e. the aforementioned list of tuples). For instance:

# %%
example_data = """
    <http://example.org/robert_capa> <http://example.org/knows> <http://example.org/henri_cartier_bresson> .
    <http://example.org/gerda_taro> <http://example.org/hasSpouse> <http://example.org/robert_capa> .
    """

example_g = rdflib.Graph()
example_result = example_g.parse(data=example_data, format='nt')

# get the number of statements (triples)
print(len(example_g))
# Out:
# 2

# %% [markdown]
# #### Parse ARTchives data from file
#
# In our case, we parse data from a **file**.
#
# Our file includes **several graphs**, hence we need to parse our data and move data in several lists of tuples. In RDFlib you do that by using the class `ConjunctiveGraph` like follows.

# %%
# create an empty Graph
g = rdflib.ConjunctiveGraph()

# parse an online RDF file by specifying the format into the graph
result = g.parse("https://raw.githubusercontent.com/marilenadaquino/information_visualization/main/2022-2023/resources/artchives.nq", format='nquads')

# %% [markdown]
# Now the graph **g** includes all the triples and the named graphs described in the file, and we can apply both python and RDFlib methods on it. For instance:

# %%
## the number of triples (quadruples)
print(len(g))
# Out:
# 5754

# %% [markdown]
# ## 2. Query RDF data
#
# Now that our graph `g` is ready, we can query the data. Queries can be done via SPARQL queries (we will see it in the next tutorial) or by using python and RDFlib methods for iterating over tuples.

# %% [markdown]
# ### 2.1 Iterate over all the graphs

# %%
for n_graph in g.contexts():
    pprint.pprint(n_graph)
# Out:
# <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/wd/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1596710882-5904682/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1573468360-52/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1598630286-3009102/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1599059093-1055605/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1598912165-7504091/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1598898560-356721/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1602245859-1839957/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559734066-09/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1601361647-8266113/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559665347-15/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1594141385-08/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559563361-99/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559131492-23/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1598474344-8067195/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559744839-57/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1582011722-53/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1557327110-46/ (<class 'rdflib.graph.Graph'>)>
# <Graph identifier=https://w3id.org/artchives/1559904986-68/ (<class 'rdflib.graph.Graph'>)>

# %% [markdown]
# ### 2.2 iterate over all the triples + context graph (i.e. quads)

# %%
for quad in g.quads():
    pprint.pprint(quad)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-richard-krautheimer'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectGenre'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q220'),
#  <Graph identifier=https://w3id.org/artchives/1559734066-09/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559659517336'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectiongustav-ludwigvermachtnis'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q1715096'),
#  <Graph identifier=https://w3id.org/artchives/1559131492-23/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559660096975'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559657936981'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559562843627'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3051533'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q1792450'),
#  <Graph identifier=https://w3id.org/artchives/1598898560-356721/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559564448313'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1641821'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('               Otto Lehmann-Brockhaus', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559563361-99/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559576216601'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                     K. Brookes', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q236958'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('           Katherine Anne Porter', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfondo-aby-warburg'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q9388534'),
#  <Graph identifier=https://w3id.org/artchives/1598630286-3009102/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionernst-kitzinger-papers-'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q48634'),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658315095'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('            B.A. Duker', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559659432985'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1599066268934'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('        Library Rights and Reproductions', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598474344-8067195/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q3057287'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q38'),
#  <Graph identifier=https://w3id.org/artchives/1559563361-99/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559657341710'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-fritz-heinemann-notizen-zur-venezianischen-malerei'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P170'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q1271052'),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q9342'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('         Palma Vecchio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-fahy'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasNotesOnSystemOfArrangement'),
#  rdflib.term.Literal('Inside the boxes, documents and photos are grouped in folders, in topographical / chronological / alphabetical order. The arrangement given by the art historian has been maintained.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionarchivio-luisa-vertova'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q3305213'),
#  <Graph identifier=https://w3id.org/artchives/1573468360-52/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-werner-cohn'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q873364'),
#  <Graph identifier=https://w3id.org/artchives/1602245859-1839957/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q55439'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                      panel painting', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557327110-46/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559659668096'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('           P. Figarolo di Gropello', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1715096'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q5'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1715096'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q5'),
#  <Graph identifier=https://w3id.org/artchives/1598912165-7504091/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q21264725'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('              Steffi Roettgen', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1573468360-52/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q70362'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('          Kurt Weitzmann', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559657942356'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionjohn-popehennessy-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q5664'),
#  <Graph identifier=https://w3id.org/artchives/1559665347-15/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionventuri-adolfo-complex-of-fonds'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P275'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559905614798'),
#  <Graph identifier=https://w3id.org/artchives/1559904986-68/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfondo-aby-warburg'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q1089074'),
#  <Graph identifier=https://w3id.org/artchives/1598630286-3009102/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionluigi-salerno-research-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q334262'),
#  <Graph identifier=https://w3id.org/artchives/1598474344-8067195/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559580126386'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1361667'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Roberto Longhi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1361667'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Roberto Longhi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557327110-46/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1361667'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Roberto Longhi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559580886649'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q585290'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('              Millard Meiss', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1573468360-52/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-otto-lehmannbrockhaus'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectGenre'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q1048669'),
#  <Graph identifier=https://w3id.org/artchives/1601361647-8266113/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionellis-k-waterhouse-notebooks-and-research-files'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasNotesOnFindingAid'),
#  rdflib.term.Literal("Series I. Notebooks, 1924-1985 67.0 notebook(s)\r\nThe notebooks are travel diaries that record in detail works seen in public and private collections, and contain alphabetical lists of paintings, artists, and monuments. These notebooks record Waterhouse's travels in the United Kingdom, the United States, and Europe, especially Italy, and the artworks seen there.\r\n\r\nSeries II. Research Files, 1801-1987 25.0 box(es)\r\nThe research files contain notes, draft catalogues and bibliographies, lectures, correspondence, photographs, notebooks, annotated books and printed catalogues (mainly of British collections). The subject matter covered includes British country houses, Reynolds, Gainsborough, El Greco, Italy and Italian Baroque art. Correspondents include art historians, curators, collectors and dealers. Photographic material includes images of paintings and photo essays on the architecture of southern Italy. Two boxes contain photocopies of diaries possibly those kept by Sir Charles Eastlake, former director of the National Gallery. The few personal items include photostats and microfiche of Waterhouse family photograph albums.", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598898560-356721/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionulrich-middledorf-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q93184'),
#  <Graph identifier=https://w3id.org/artchives/1598912165-7504091/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/1598630286-3009102/'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Aby Warburg'),
#  <Graph identifier=https://w3id.org/artchives/1598630286-3009102/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559657126517'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559574526114'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-zeri'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectArtist'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q2886111'),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q13375'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('         Pisa'),
#  <Graph identifier=https://w3id.org/artchives/1559904986-68/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559580014197'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-fahy'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeriod'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q7018'),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2044'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                        Florence'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559580317718'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                 (-) Brice', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559564634678'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658443897'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('            G. Eimer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-wolfgang-lotz'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q27144556'),
#  <Graph identifier=https://w3id.org/artchives/1582011722-53/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-kurt-badt'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P571'),
#  rdflib.term.Literal('1956', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear')),
#  <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559575999866'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q88907'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q183'),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q339759'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P17'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q38'),
#  <Graph identifier=https://w3id.org/artchives/1601361647-8266113/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionleo-steinberg-research-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q3305213'),
#  <Graph identifier=https://w3id.org/artchives/1599059093-1055605/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q7991'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('natural science', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598630286-3009102/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/1559131492-23/'),
#  rdflib.term.URIRef('http://www.w3.org/ns/prov#wasGeneratedBy'),
#  rdflib.term.URIRef('https://w3id.org/artchives/marilena-dot-daquino2-at-unibo-dot-it'),
#  <Graph identifier=https://w3id.org/artchives/1559131492-23/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1641821'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q5'),
#  <Graph identifier=https://w3id.org/artchives/1601361647-8266113/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658391392'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('            M.F. Edgerton', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionventuri-adolfo-complex-of-fonds'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q9388534'),
#  <Graph identifier=https://w3id.org/artchives/1559904986-68/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-fahy'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P217'),
#  rdflib.term.Literal('FZ.2017.Fahy', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559580970624'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q8459'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('     Giorgione', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598898560-356721/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559574535530'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                     J.A. Boromé', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559659653206'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559657624586'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658031861'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('             A. Dörfler', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559576010710'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                     R.J. Braidwood', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559660089711'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/biblioOnArtHistorian'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal("Sorensen, L. (Ed.). Salerno, Luigi. In Dictionary of Art Historians;\r\nFusconi, G. (2007). Luigi Salerno. In Dizionario biografico dei soprintendenti storici dell'arte, 1904-1975. Bologna: Bononia University Press;", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598474344-8067195/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionluigi-salerno-research-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q56055236'),
#  <Graph identifier=https://w3id.org/artchives/1598474344-8067195/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1715096'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P569'),
#  rdflib.term.Literal('1901', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1715096'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P569'),
#  rdflib.term.Literal('1901', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear')),
#  <Graph identifier=https://w3id.org/artchives/1598912165-7504091/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559657630543'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionellis-k-waterhouse-notebooks-and-research-files'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasMainObjectType'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q43013'),
#  <Graph identifier=https://w3id.org/artchives/1598898560-356721/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559575974755'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q16244'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('         Province of Pisa'),
#  <Graph identifier=https://w3id.org/artchives/1559904986-68/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q55453618'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q220'),
#  <Graph identifier=https://w3id.org/artchives/1557327110-46/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionernst-kitzinger-papers-'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasScopeAndContentSubject'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q964573'),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559659629338'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectiongustav-ludwigvermachtnis'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q28823'),
#  <Graph identifier=https://w3id.org/artchives/1559131492-23/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/1598630286-3009102/'),
#  rdflib.term.URIRef('https://w3id.org/artchives/publicationStage'),
#  rdflib.term.Literal('modified', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598630286-3009102/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q2309545'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('             Michele Tosini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559576316455'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                     E. Brunetti', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658679493'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-fahy'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasCataloguingStandard'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1557322702284'),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q191423'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Domenico Ghirlandaio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559574671369'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionjulius-s-held-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q18342317'),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559580977432'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                A.M. Cetto', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionarchivio-luisa-vertova'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q320152'),
#  <Graph identifier=https://w3id.org/artchives/1573468360-52/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559580719226'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559576437111'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionulrich-middledorf-papers'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasCataloguingStandard'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q3878224'),
#  <Graph identifier=https://w3id.org/artchives/1598912165-7504091/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658126575'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('            L. Döry', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q23619996'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                      Antonio Trentanove', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557327110-46/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658295366'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559564203274'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-zeri'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectObject'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q860861'),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658194239'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('            E. Drey', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1089074'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q170027'),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q12554'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P582'),
#  rdflib.term.Literal('1500-01-01T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')),
#  <Graph identifier=https://w3id.org/artchives/wd/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559564713607'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559580051397'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/1601361647-8266113/'),
#  rdflib.term.URIRef('http://www.w3.org/ns/prov#generatedAtTime'),
#  rdflib.term.Literal('2020-10-23T11:50:28.124000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime')),
#  <Graph identifier=https://w3id.org/artchives/1601361647-8266113/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-fritz-heinemann-notizen-zur-venezianischen-malerei'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasOtherNotes'),
#  rdflib.term.Literal('The collection is relevant for Venetian Studies and Provenance Research\r\n\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559579900325'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559564435306'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                         P. Billeter', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-richard-krautheimer'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q3161414'),
#  <Graph identifier=https://w3id.org/artchives/1559734066-09/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559579487229'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559579806160'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionleo-steinberg-research-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q5764634'),
#  <Graph identifier=https://w3id.org/artchives/1599059093-1055605/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1629748'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P800'),
#  rdflib.term.URIRef('https://w3id.org/artchives/artHistorianBibliography'),
#  <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-zeri'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasHistoricalNotes'),
#  rdflib.term.Literal('On 24th March 1947, Federico Zeri wrote to Berenson to confess that his photograph library was still "small and ill-organized". It was around the same time that clarity and order were given to the ambitious project that would result in one of the world\'s most complete private archives for the art history sector. Over the years whole photograph collections previously owned by scholars, auction houses and antique dealers were saved by Zeri from dispersion or destruction. He collected photographic campaigns, complete with paintings, on historic building complexes and fresco cycles. Many important works that have now been irretrievably lost or have sunk without trace are only documented by photos from his archive. The photograph archive numbers 290,000 photos of art works, arranged by the scholar in some 10,000 folders in their turn contained in over 1,000 files. For the most part they are black and white prints (gelatin and albumen prints on paper), with a smaller section of colour prints and slides from State photography archives (ICCD, Soprintendenze), Italian and foreign museums, archives and private collections. The photographic collection copiously documents the scholar’s own favourite research field (Italian painting and sculpture from the thirteenth to the eighteenth century), but also includes sets devoted to archaeology, architecture, painting and sculpture of the nineteenth and twentieth centuries, as well as to applied arts, drawing, miniature and European painting. In some sectors, the quantity of pictures is well-nigh exhaustive of the subject. Most of the reproductions bear notes in his hand on the back, and these afford a wealth of information much-needed by research (bibliographical references, provenances, cross-references to other works, alternative attributions).\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559564461656'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                         G. Bing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionulrich-middledorf-papers'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectObject'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q93184'),
#  <Graph identifier=https://w3id.org/artchives/1598912165-7504091/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559657256393'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('              B. Degenhart', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559654407794'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559563486648'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                           M. Barsanti;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559576179201'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                     H. Brinkmann', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1271052'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P27'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q183'),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559579566979'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q365852'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('       Arnold Hauser', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559658037021'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionjulius-s-held-papers'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasScopeAndContentSubject'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q150679'),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-zeri'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P571'),
#  rdflib.term.Literal('1999', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear')),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q55453618'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P569'),
#  rdflib.term.Literal('1962', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear')),
#  <Graph identifier=https://w3id.org/artchives/1557327110-46/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionernst-kitzinger-papers-'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q19754137'),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionernst-kitzinger-papers-'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeriod'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q12554'),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-fritz-heinemann-notizen-zur-venezianischen-malerei'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q347842'),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559905614798'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
# ...
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559576300734'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-richard-krautheimer'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q123466'),
#  <Graph identifier=https://w3id.org/artchives/1559734066-09/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1712683'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q2994387'),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559657341710'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionjulius-s-held-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q209050'),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-kurt-badt'),
#  rdflib.term.URIRef('http://www.w3.org/1999/02/22-rdf-syntax-ns#type'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q9388534'),
#  <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/1559744839-57/'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Eugenio Battisti'),
#  <Graph identifier=https://w3id.org/artchives/1559744839-57/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q995470'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P106'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q81096'),
#  <Graph identifier=https://w3id.org/artchives/1594141385-08/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559657499836'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q160538'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Gian Lorenzo Bernini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557327110-46/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559132053777'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                 sketch', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559131492-23/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559652371596'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('          Italy'),
#  <Graph identifier=https://w3id.org/artchives/1559131492-23/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-kurt-badt'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasHistoricalNotes'),
#  rdflib.term.Literal('The origin of the fund seems partially to go back to the years when, escaped German racial laws, Badt lived for a while in Florence but the fund contains also more recents documents dating to the immediate post-war period.\r\n\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1089074'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P569'),
#  rdflib.term.Literal('1921', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear')),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559564415604'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionjulius-s-held-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q5598'),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559579834223'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q14378'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('               neoclassicism', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1573468360-52/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfondo-aby-warburg'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P217'),
#  rdflib.term.Literal('KHI - WAR', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598630286-3009102/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559657390680'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('              Th.C. Denise', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-fahy'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q610687'),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/biblioOnArtHistorian'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('Sorensen, L., (Ed.). Middeldorf, Ulrich. In Dictionary of Art Historians;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598912165-7504091/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1296486'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('            Wolfgang Lotz', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559734066-09/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1598457992900'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('         painting,', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559657390680'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionernst-kitzinger-papers-'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectObject'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q133067'),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559564276165'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559579338206'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                   R. Chiarelli', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionjohn-popehennessy-papers'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasScopeAndContentSubject'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q49210'),
#  <Graph identifier=https://w3id.org/artchives/1559665347-15/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559575999866'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-zeri'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q9134'),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/1598474344-8067195/'),
#  rdflib.term.URIRef('http://www.w3.org/ns/prov#wasInfluencedBy'),
#  rdflib.term.URIRef('https://w3id.org/artchives/francesca-dot-mambelli6-at-unibo-dot-it'),
#  <Graph identifier=https://w3id.org/artchives/1598474344-8067195/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-fahy'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q1278452'),
#  <Graph identifier=https://w3id.org/artchives/1557325562-63/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559576065957'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559658256408'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q6936496'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('        Creative Commons Attribution-NonCommercial', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ulrich-middeldorf'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectPeople'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1559658379498'),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q37853'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('           baroque', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1598898560-356721/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionjulius-s-held-papers'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q43270'),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-fritz-heinemann-notizen-zur-venezianischen-malerei'),
#  rdflib.term.URIRef('https://w3id.org/artchives/hasSubjectObject'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1598457992900'),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q1712683'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q1465805'),
#  <Graph identifier=https://w3id.org/artchives/1559595129-89/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559574584713'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#comment'),
#  rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-fritz-heinemann-notizen-zur-venezianischen-malerei'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P127'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q872398'),
#  <Graph identifier=https://w3id.org/artchives/1598354394-1608677/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionernst-kitzinger-papers-'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('https://w3id.org/artchives/MD1573472299495'),
#  <Graph identifier=https://w3id.org/artchives/1598549633-5271676/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1559659929933'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('           K.W. Forster', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1559134510-33/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('http://www.wikidata.org/entity/Q131808'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('  Mannerism', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-kurt-badt'),
#  rdflib.term.URIRef('http://www.wikidata.org/prop/direct/P921'),
#  rdflib.term.URIRef('http://www.wikidata.org/entity/Q211133'),
#  <Graph identifier=https://w3id.org/artchives/1594144112-97/ (<class 'rdflib.graph.Graph'>)>)
# (rdflib.term.URIRef('https://w3id.org/artchives/MD1556356158493'),
#  rdflib.term.URIRef('http://www.w3.org/2000/01/rdf-schema#label'),
#  rdflib.term.Literal('                                         galleria Sangiorgi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string')),
#  <Graph identifier=https://w3id.org/artchives/1557321703-04/ (<class 'rdflib.graph.Graph'>)>)

# %% [markdown]
# ### 2.3 Iterate over all terms of the quads

# %%
# iterate over all terms of the quads
for subj, pred, obj, context in g.quads():
    pprint.pprint(obj)
# Out:
# Output streaming troncato alle ultime 5000 righe.
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q31855')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q31855')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q31855')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q31855')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q31855')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q31855')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q31855')
# rdflib.term.Literal('The photo library is divided into sections according to the different typologies of art objects documented in the photos. Besides its rich Italian painting collection (150,000 photographs), the archive contains sizable core collections covering Italian sculpture (17,000), Italian and European Still Life (14,400 photos), "Non-Italian art" (), Archaeology (5,300), Architecture (8,800), Drawings (12,700), the Applied arts (18,000 photos), Miniatures (5,500), Fakes ().  Inside the boxes photos are kept inside folders bearing the artists\' names. Phototypes are 100% positives, for the most part black and white prints on paper: gelatin silver prints, albumen prints, carbon prints, collotypes, photogravures, with a smaller section of color prints and transparencies.\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           Leo Steinberg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q30755')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559575949702')
# rdflib.term.Literal('published', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Kornél Fabriczy')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q7814')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q220')
# rdflib.term.Literal('University of Freiburg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('University of Freiburg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                            R.F. Arragon', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q220')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           C. Faerber', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q7018')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Vittore Carpaccio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564461656')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580387272')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q517')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q50641')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q59529805')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q178588')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q860861')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579891215')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q60185')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q9440')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q47551')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579984547')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559581036617')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658685912')
# rdflib.term.Literal('              Victoria and Albert Museum', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('aestheticism', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 photograph', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q192720')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579878261')
# rdflib.term.Literal('                     W. Brenneke', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5599')
# rdflib.term.Literal('  Middle Ages', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q9388534')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q166118')
# rdflib.term.Literal(' \tSeries I. Writings, 1932-1995\r\n\tSeries II. Various Research Projects (unpublished), 1968-1993\r\n\tSeries III. Lectures, 1931-1990\r\n\tSeries IV. Harvard Courses, 1960, 1968-1978\r\n\tSeries V. Harvard Seminars, 1947-1979\r\n\tSeries VI. Floor Mosaics, n.d.\r\n\tSeries VII. Cleveland Marbles, 1966-1979, n.d.\r\n\tSeries VIII. Various Topics (research files and correspondence), , 1962-1994 n.d.\r\n\tSeries IX. Various Matters (professional activities and other writings), 1942-1943, 1956, 1961-1986\r\n\tSeries X. Photographs, 1937-1991, n.d.\r\n\tSeries XI. Slides, n.d.\r\n\tSeries XII. Negatives, 1937, 1943, n.d.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     St. Bottari', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1601366693003')
# rdflib.term.Literal('1937', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('       Carlo Tridenti ', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q183')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579925655')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/artHistorianBibliography')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('CASNS AV', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('    Il patrimonio perduto nelle fotografie di Federico Zeri, Bologna, 2014, Fondazione Federico Zeri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q63425235')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q11203476')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658044253')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q373916')
# rdflib.term.Literal('           S. Ferrali', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5667416')
# rdflib.term.Literal('After graduating in philosophy in Turin, he later began his studies in history of art and architecture. He was Professor of History of Architecture at the Universities of Florence, Milan, Reggio Calabria and Tor Vergata in Rome, and History of Art in Genoa and Pennsylvania State University. He created the "Experimental Museum of Contemporary Art" in Turin and founded and directed the magazine "Marcatrè".\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5669')
# rdflib.term.Literal('          Venetian Paintings and Drawings', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658142364')
# rdflib.term.Literal('                           Carlo Crivelli', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q215999')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q37853')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580374279')
# rdflib.term.Literal('        Mannerism', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1596724492768')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580515216')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q13371')
# rdflib.term.Literal('Federico Zeri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Federico Zeri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Federico Zeri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q63078')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q34627')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q14378')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1277575')
# rdflib.term.URIRef('https://w3id.org/artchives/francesca-dot-mambelli6-at-unibo-dot-it')
# rdflib.term.Literal('      M. Sacchetti ', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q504949')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q6955')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564747480')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3901455')
# rdflib.term.Literal('Vienna', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     P. Brieger', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q34627')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2629038')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q334262')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564857736')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3779126')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q90407')
# rdflib.term.Literal('1770-01-01T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.Literal('  16th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1089074')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576316455')
# rdflib.term.Literal('   Davidsohn', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3147735')
# rdflib.term.Literal('                         W. Boll', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q215999')
# rdflib.term.Literal('1800-01-01T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658692837')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            Encyclopaedia Americana', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q860861')
# rdflib.term.Literal('                              province Florence')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q697096')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658323682')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659517336')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5598')
# rdflib.term.Literal('                     I.M. Botto', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('     clipping', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q213439')
# rdflib.term.Literal('         15th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('         15th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           art critic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('about 355 cardboard boxes (320 of documents and 35 of photographs)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576017812')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q50914856')
# rdflib.term.Literal('             U. Donati', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q366081')
# rdflib.term.Literal('       Louvre Museum', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Galleria Estense', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q60185')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1598618665850')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1256999')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1435690')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2528876')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5092')
# rdflib.term.Literal('                R. Causa', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('        Museum of Fine Arts, Boston', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://catalogo.fondazionezeri.unibo.it/scheda.livello.jsp?id_padre=&id=2&tipo_scheda=fondo&decorator=layout_resp&apply=true&locale=it')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q464266')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q88907')
# rdflib.term.Literal('              A. Dierich', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             panel painting', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660252930')
# rdflib.term.Literal('                S. Camerani', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660132952')
# rdflib.term.Literal('            J. Dufner', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q205148')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580317718')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564665026')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q55044')
# rdflib.term.Literal('               bequest', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658542725')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('               William Shakespeare', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3161414')
# rdflib.term.Literal("              Ch. D'Halloy", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-otto-lehmannbrockhaus')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3305213')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q318769')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/collectionfondo-aby-warburg')
# rdflib.term.Literal('                      Italy')
# rdflib.term.Literal('  Anton Heinrich Springer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2632216')
# rdflib.term.Literal('           Gary Schwartz', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 Ch. E. Buckley', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/marilena-dot-daquino2-at-unibo-dot-it')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal("         Palazzo Vitelli a Sant'Egidio", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659778597')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580399817')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q55044')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1361667')
# rdflib.term.Literal('                      17th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('detailed inventory (further cataloging in progress)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Roberto Longhi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q16970')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564203274')
# rdflib.term.Literal('                           15th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1801-01-01T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q103498')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658623241')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q359047')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657966349')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q500242')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q170022')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564288346')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658136008')
# rdflib.term.URIRef('https://w3id.org/artchives/mhatam-at-getty-dot-edu')
# rdflib.term.Literal('online catalog')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1089074')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659838667')
# rdflib.term.Literal("Correspondence and information are available in other KHI in Florenz's Archival Collections.\r\n\r\n", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('private biographic material, post cards, working material for studies in Italian medieval art, excerpts from archival documents, diaries, manuscripts for books, articles and conferences.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658671274')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1361667')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5828092')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q152087')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559651933702')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564383715')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q7015')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           D. Frey', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579617165')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559654368128')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q365852')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5743139')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658037021')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559563255440')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q359047')
# rdflib.term.Literal('Anthony van Dyck', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1599150087448')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q8683')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 Cattedrale di Monreale', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q37853')
# rdflib.term.Literal('              O. Del Mazza', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579521891')
# rdflib.term.Literal('                           Master of the Hartford Still-Life', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3057287')
# rdflib.term.Literal('          W. Gramberg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564239176')
# rdflib.term.Literal('Siena', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/artHistorianBibliography')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-werner-cohn')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657312144')
# rdflib.term.Literal('              A. De Bosque', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              J. Dillenberger', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1515397')
# rdflib.term.Literal('              Borromeo', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660161765')
# rdflib.term.Literal('modified', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564704717')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q66209')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q59533353')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q174705')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5669')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559568562249')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564773757')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q742157')
# rdflib.term.Literal('        Bernard Berenson', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q872398')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q152087')
# rdflib.term.Literal('           E.F. Fabeni', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Giovanni di Paolo', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3621743')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1712683')
# rdflib.term.URIRef('https://w3id.org/artchives/francesca-dot-mambelli6-at-unibo-dot-it')
# rdflib.term.Literal('      Nicholas Bacon', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564252626')
# rdflib.term.Literal('                         W. Boeck', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1345')
# rdflib.term.Literal('                     G. Bosi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q159297')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3147735')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1747398')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580374279')
# rdflib.term.Literal('      DACS', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1296486')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q182046')
# rdflib.term.Literal('Venus', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q161439')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659702863')
# rdflib.term.Literal('3,855 photographs and postcards\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              R.S. Davis', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            L. Dussler', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q49210')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q40960534')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q154804')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q57656')
# rdflib.term.Literal('                  M. Crespi Morbio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('My online catalog')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q93184')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q19754137')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559568381166')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658364434')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657322352')
# rdflib.term.Literal('  portrait', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q175566')
# rdflib.term.Literal('             G. Dogar', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657304305')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657955639')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('      Library Rights and Reproductions', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1237218')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657791000')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579465565')
# rdflib.term.Literal('                D. Cantimori', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           M.F. Fischer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             newspaper clipping', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('conditions for reproduction', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q595597')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q70362')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659749864')
# rdflib.term.URIRef('https://w3id.org/artchives/marilena-dot-daquino2-at-unibo-dot-it')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1289734')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3339070')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q108748')
# rdflib.term.Literal("Fahy, E. (1976). Some Followers of Domenico Ghirlandaio. New York: Garland; \r\nFahy, E. (1973). The Wrightsman Pictures. New York: Metropolitan Museum of Art; \r\nFahy, E. (1979). The Legacy of Leonardo: Italian Renaissance Paintings from Leningrad. Washington, DC: National Gallery of Art; \r\nFahy, E. (1983). Metropolitan Flowers. New York: Abrams; \r\nFahy, E. (2000). L' Archivio storico fotografico di Stefano Bardini: Dipinti, disegni, miniature, stampe. Firenze: Bruschi;", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579321700')
# rdflib.term.Literal('       Rudolf Wittkower', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     W. Brücker', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                E. Carli', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q55439')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559575983889')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal(' ', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     Ch. Boucaud', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658295366')
# rdflib.term.Literal('documents and photographs are grouped in folders', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5669')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')
# rdflib.term.Literal('                            F.A. Bernett;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1598618187338')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             writer')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1048826')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657256393')
# rdflib.term.Literal('cataloguing standard', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              D. Danesi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559581044054')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q37030')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1510510')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5597')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1644597')
# rdflib.term.URIRef('https://w3id.org/artchives/collectiongustav-ludwigvermachtnis')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q47551')
# rdflib.term.Literal('                         S. Bodmer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1960', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('              Isabella Stewart Gardner Museum', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('archival collection', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q161439')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1425008')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q168496')
# rdflib.term.Literal('                     A.M. Brizio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q309736')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579988846')
# rdflib.term.Literal('           G. Fiani', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     Rasponi palace', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579433916')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580467702')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              curator')
# rdflib.term.Literal('2018', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal("Sir John Wyndham Pope-Hennessy (1913-1994) was a British art historian, museum director, curator, and an expert on Italian Renaissance sculpture and painting. He served as director of both the Victoria and Albert Museum (1967-1973) and the British Museum (1974-1976). In 1977, he became Chairman of the Department of European Paintings at the Metropolitan Museum of Art and professor of art history at New York University's Institute of Fine Arts. Sienese Quattrocento painting was Pope-Hennessy's first field of research and was marked by his monograph on the painter Giovanni di Paolo. However, his greatest contribution to the history of art is perhaps his research and writing on Italian sculpture, which profited from his decades-long work with the rich sculpture collection at the Victoria and Albert Museum. His three-volume Introduction to Italian Sculpture has remained an important reference work and was followed by studies on Donatello, bronze statuettes, and Italian plaquettes.\r\n\r\n", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q37562')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q38')
# rdflib.term.Literal('840024', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559843561028')
# rdflib.term.Literal('                 Florence')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Festschrift für U. M., 1968 (P); \r\nKeutner, H. (1983). Mitt. d. Kunsthist. Inst. Florenz 27, 256-60; \r\nRadcliffe, A. (2008). Ulrich Middeldorf (1901 - 1983). Obituaries, 175-179; \r\nRadcliffe, A. (1984). Burlington Magazine, 126, 288-90; \r\nRoberts, P. L. (2013). Ulrich A. Middeldorf (1901-83) and textiles, The Getty research journal, 5, 189-196; \r\nCollareta, M. (2018). Ulrich Middeldorf (1901-1983), curiosità e "connoisseurship". In F. Caglioti, A. De Marchi, & A. Nova (Eds.), I conoscitori tedeschi tra Otto e Novecento. Milano: Officina Libraria, 466-471;\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564535522')
# rdflib.term.Literal('           J. Fleming', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576291663')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1622272')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3494271')
# rdflib.term.Literal('                 art historian')
# rdflib.term.Literal('                 art historian')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576300734')
# rdflib.term.Literal("           Michelangelo's Piet�s.", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q59945')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1034868')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q860861')
# rdflib.term.Literal('artistic genre or theme', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564511302')
# rdflib.term.Literal('profession')
# rdflib.term.Literal('        Julius S. Held', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580892843')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q9388534')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579526580')
# rdflib.term.Literal('                         B. Black', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('        Cenobio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659941627')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580350945')
# rdflib.term.URIRef('https://primo.getty.edu/permalink/f/19q6gmb/GETTY_ALMA21132644220001551')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q359047')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q160538')
# rdflib.term.Literal('Luigi Salerno', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              E.M. De Leeuw', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Collection Inventories and Finding Aids')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('         Margaret Barr Scolari', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q150679')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1373290')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('acquisition type', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559575942459')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q37853')
# rdflib.term.URIRef('https://w3id.org/artchives/marilena-dot-daquino2-at-unibo-dot-it')
# rdflib.term.Literal('                     A. Brand', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q7018')
# rdflib.term.Literal('         furniture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574678841')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q435989')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574638885')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1465270')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Harvard University', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('archival collection', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           15th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q807815')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579312587')
# rdflib.term.Literal('           F. Forster-Hahn', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580664098')
# rdflib.term.Literal('1900-01-01T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5547')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q88907')
# rdflib.term.Literal('Switzerland', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                           Vittorio Cini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Pompeo Molmenti', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Battisti Eugenio (complex of fonds)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659633394')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2527217')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q7034')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             Germany')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3494271')
# rdflib.term.Literal('       Detlev von Hadeln', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('               Leonardo da Vinci', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5681')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# ...
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q52905023')
# rdflib.term.Literal('Stuttgart', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1162163')
# rdflib.term.Literal('             Jacopo da Sellaio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1934', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1622272')
# rdflib.term.Literal('           Willibald Sauerländer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal("Series I. Clippings files, ca. 1925-1981 7.09 Linear Feet\r\nSeries contain articles, photographs and other printed images taken from publications, and very occasionally, notes and letters, organized by subject (ca. 9 linear ft.). Subjects include individual costumes, textiles an other minor arts, decorative arts, drawings, sculpture, medals.\r\n\r\nSeries II. Letters and bibliographic notes, ca. 1925-1981 ca. 2 lin. ft.\r\nSeries contains letters from scholars and colleagues and bibliographic notes, most of which were pulled from Middeldorf's books, now in the Getty Research Library. One file of ca. 30 items consists of photocopies of letters between Bernard Berenson and J. Paul Getty, 1956.\r\n\r\nSeries III. Journals and offprints, ca. 1925-1981 8.5 Linear Feet\r\nPublications sent to and collected by Middeldorf contain articles by colleagues, reviews of books, and articles of interest to Middeldorf for his research.\r\n\r\nSeries IV. Annotated books, ca. 1925-1981 ca. 7.5 lin. ft.\r\nSeries includes items from Middeldorf's library which contain significant or extensive annotations. Annotations are by Middeldorf unless otherwise noted. Also includes some notes, mss and printed matter, including scant correspondence, found in the books in his library.\r\n\r\nSeries V. Bibliographic files, ca. 1925-1981 117 box(es) ca. 25 lin. ft.\r\nSeries comprises a bibliography on index cards, small photographs and postcards organized by subject. Topics include: Italian art and artists, Renaissance medals, minor arts (textiles, wood, ceramics, metal), sculpture, drawings, iconography, decorative arts, art in fiction, architecture, painting, and historiography.", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579637742')
# rdflib.term.Literal('        notes', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564196827')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564155051')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657608743')
# rdflib.term.Literal('John Pope-Hennessy papers', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           art history', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q170571')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q41493')
# rdflib.term.Literal('       Gert von der Osten', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559652371596')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q338367')
# rdflib.term.Literal('Richard Krautheimer published an autobiographical essay as an introduction to his Ausgewählte Aufsätze zur europäischen Kunstgeschichte, Cologne 1988, pp. 7-37 (engl. version in: Rome. Tradition, innovation, renewal, Rome 1991, pp. 93-126); \r\nKliemann, J. (Ed.). (1997). In memoriam Richard Krautheimer: relazioni della giornata di studi, Roma, 20 febbraio 1995, Palazzo dei Conservatori. Rome: Biblioteca Hertziana; \r\nWendland, U. (1999). Biographisches Handbuch deutschsprachiger Kunsthistoriker im Exil: Leben und Werk der unter dem Nationalsozialismus verfolgten und vertriebenen Wissenschaftler (vol 1., pp-377-86). Munich: K. G. Saur; \r\nKinney, D. (2002). Richard Krautheimer at the Institute of Fine Arts. Byzantinische Forschungen, 27, 177-195; \r\nFrancisci Osti, O. (2004). Richard Krautheimer. In Dizionario Biografico degli Italiani (vol. 62, pp. 772-774). Roma: Istituto della Enciclopedia Italiana; \r\nMaurer, G. (2008). Richard Krautheimer (1887-1994). in U. Pfisterer (Ed.), Klassiker der Kunstgeschichte (vol. 2, pp. 90-106). Munich: Beck;\r\nKinney, D. (2013). Civis romanus: Richard Krautheimer. In S. Ebert-Schifferer (Ed.), 100 Jahre Bibliotheca Hertziana – Max-Planck-Institut für Kunstgeschichte. Die Geschichte des Instituts 1913-2013 (pp. 192-199). Munich: Hirmer;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('cataloguing standard', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('cataloguing standard', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('cataloguing standard', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('cataloguing standard', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580801442')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660066082')
# rdflib.term.Literal('                  writing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                          M. Berchtold', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('The collection is relevant for 17th and 18th century Italian Baroque studies.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659962194')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')
# rdflib.term.Literal('     photograph', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('     photograph', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('archival collection', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     G. Bowers', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/collectionulrich-middledorf-papers')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579445788')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564180540')
# rdflib.term.Literal('1501-01-11T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q99')
# rdflib.term.Literal('bestiary', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                  A. Coffin', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             typescript', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3889631')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657455570')
# rdflib.term.Literal('modified', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q487623')
# rdflib.term.Literal('                E. Castelnuovo', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657359130')
# rdflib.term.Literal('           M. Fischel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Duchess Sibylle of Saxe-Lauenburg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('    Thomas Mann', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 ancient art', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Harvard University Center for Italian Renaissance Studies', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            Erwin Panofsky', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Nazi Party', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/collectionfototeca-fahy')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q102272')
# rdflib.term.Literal('33.0 linear feet (55 boxes)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('2018', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580051397')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579827876')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1557322702284')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3494271')
# rdflib.term.Literal('1994', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q28811016')
# rdflib.term.Literal('1750-01-01T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2277510')
# rdflib.term.Literal('Kornél Fabriczy', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     D. Brandt', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q174705')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q166118')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659814126')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q50637')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657425240')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559563478513')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658219635')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q284742')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q93184')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q41264')
# rdflib.term.Literal('                         J. Bier', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q123466')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2994387')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657341710')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q209050')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q9388534')
# rdflib.term.Literal('Eugenio Battisti')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q81096')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Gian Lorenzo Bernini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 sketch', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('          Italy')
# rdflib.term.Literal('The origin of the fund seems partially to go back to the years when, escaped German racial laws, Badt lived for a while in Florence but the fund contains also more recents documents dating to the immediate post-war period.\r\n\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1921', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5598')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579834223')
# rdflib.term.Literal('               neoclassicism', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('KHI - WAR', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Th.C. Denise', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q610687')
# rdflib.term.Literal('Sorensen, L., (Ed.). Middeldorf, Ulrich. In Dictionary of Art Historians;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            Wolfgang Lotz', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('         painting,', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q133067')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564276165')
# rdflib.term.Literal('                   R. Chiarelli', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q49210')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559575999866')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q9134')
# rdflib.term.URIRef('https://w3id.org/artchives/francesca-dot-mambelli6-at-unibo-dot-it')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1278452')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576065957')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('        Creative Commons Attribution-NonCommercial', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658379498')
# rdflib.term.Literal('           baroque', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q43270')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1598457992900')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1465805')
# rdflib.term.Literal('person or organization', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q872398')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1573472299495')
# rdflib.term.Literal('           K.W. Forster', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('  Mannerism', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q211133')
# rdflib.term.Literal('                                         galleria Sangiorgi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))

# %% [markdown]
# ### 2.4 Manipulate single elements of the triple/ quad.
#
# For instance, we can get the **list of objects** as a set and work on the unique values of the list. To this extent, we can mix both RDFlib methods and python built-in methods to work on RDF data as any other type of data.

# %%
unique_objs = set()
for subj, pred, obj, context in g.quads():
    unique_objs.add(obj)
    
for obj in unique_objs:
    pprint.pprint(obj)
# Out:
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q155057')
# rdflib.term.Literal('Gustav Ludwig')
# rdflib.term.Literal('       E. Weddingen', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('        Mannerism', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('2020-10-13T11:56:02.372000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5681')
# rdflib.term.Literal('               Bibliotheca Hertziana %u2013 Max Planck Institute of Art History', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                           Renaissance', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q30755')
# rdflib.term.Literal('            early Christian art and architecture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659941627')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q667276')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q978185')
# rdflib.term.Literal('KHI - WAR', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('University of Virginia', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559562187391')
# rdflib.term.Literal('The collection is relevant for 17th and 18th century Italian Baroque studies.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Skulpturensammlung Dresden', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 Libro di Antonio Billi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Peter Paul Rubens', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            M.F. Edgerton', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 ICCD-F', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('  Wilhelm von Bode', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('   Federico Zeri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559562867390')
# rdflib.term.Literal('                ISAD', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('alphabetical order by people Name; inventory and cataloging conducted 80% (card cleaning)\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1987', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658636971')
# rdflib.term.Literal('1977', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('Aby Warburg', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Columbia University', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Dedalo', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              G. Delbanco', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Sorensen, L., (Ed.). Middeldorf, Ulrich. In Dictionary of Art Historians;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('  painting', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal(' Getty Research Institute', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576252213')
# rdflib.term.Literal('              H. Decker', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           manuscript', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658611482')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658443897')
# rdflib.term.Literal('Shirey, D. L. (1973, May 20). Everett Fahy of the Met Is Named Frick Director. New York Times, 63; \r\nRussell, J. (1986, July 31). New Head of European Art at Met. New York Times, 16;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                G. Campana', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Denis Mahon', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            R.L. Ducote', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                  W.S. Cook', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Harvard University', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q19753933')
# rdflib.term.Literal('2020-10-13T12:30:49.693000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579862012')
# rdflib.term.Literal('Switzerland', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                         L. Blumenthal', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579577679')
# rdflib.term.Literal('Agosti, G. (Ed.). (1990-1995). Archivio di Adolfo Venturi. Pisa: Scuola Normale Superiore;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576017812')
# rdflib.term.Literal('                  Germany')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579891215')
# rdflib.term.Literal('       maiolica', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                W.H. Capps', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                           Alessandro Contini Bonacossi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1866', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q297565')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659743324')
# rdflib.term.Literal('              Tuscany', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q6955')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580886649')
# rdflib.term.Literal('2020-10-13T12:27:05.949000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.Literal('                           Europeana', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              M.P. De Leon', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658406236')
# rdflib.term.Literal('                                    ICCD-OA', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580738128')
# rdflib.term.Literal('Julius S. Held')
# rdflib.term.Literal('       painting', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Jacopino del Conte', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            Renaissance architecture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://primo.getty.edu/permalink/f/19q6gmb/GETTY_ALMA21132644220001551')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564435306')
# rdflib.term.Literal('           Creative Commons license', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                I. Cardellini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q66209')
# rdflib.term.Literal('       independent scholar')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657532537')
# rdflib.term.Literal('University of Rostock', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           S.L. Faison', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q178588')
# rdflib.term.Literal('                      drawing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q872398')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q14552560')
# rdflib.term.Literal('         history painting', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q107425')
# rdflib.term.Literal('                A. Campana', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('    Friedrich Nietzsche', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Documents are grouped in folders by subject and chronological order', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658596902')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576437111')
# rdflib.term.Literal('                   G.M. Clough', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5828092')
# rdflib.term.Literal('                         V. Bindi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q503176')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q49850')
# rdflib.term.Literal('            Karl Lehmann', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658271466')
# rdflib.term.Literal("Ulrich Alexander Middeldorf, born in 1901, was a German-American art historian who specialized in the study of sculpture, medals, and the minor and applied arts. He was director of the Art Institute of Chicago, the Longhi Institute, and then served as the director and librarian of the Kusthistorisches Institute until his death in 1983.\r\n\r\nIn addition to his research specializations, Middeldorf had an abiding interest in Italian art, and a collector's passion for the connection between art and fiction. He assembled a collection of fiction, much of it popular, paperback works, which include characters or plot lines that relate to art (artists, art history, forgery, etc.). This collection of Art in Fiction was acquired by the Getty Research Institute Library in 1984. Middeldorf's correspondence with Sybille Pantazzi about his art in fiction collecting and other interests (1966-1983) may be seen in Special Collections Accession no. 950004.", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                  A. Czobor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q6986279')
# rdflib.term.Literal('                   E. Chirol', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('    Architecture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                  gelatin silver process', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                         B. Bilzer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564754552')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q208165')
# rdflib.term.Literal('Wilhelm Lehmbruck', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580552207')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580365069')
# rdflib.term.Literal('        Renaissance', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('      drawing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559568315600')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579968421')
# rdflib.term.URIRef('https://w3id.org/artchives/collectionjulius-s-held-papers')
# rdflib.term.Literal('                          C. Bertelli', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657284529')
# rdflib.term.Literal('              A. Dietz', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659404912')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657950295')
# rdflib.term.Literal('online catalog')
# rdflib.term.Literal('2020-10-25T11:38:50.390000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.Literal('               Bernardino Licinio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                           carbon', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('American poetry', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                         G. von Bock', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657263303')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q17166797')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564223738')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659697209')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580460615')
# rdflib.term.Literal("Howard, D. (1995). Lotz's Text: Its Achievement and Significance. In W. Lotz, Architecture in Italy 1500-1600 (pp. 1-7). New Haven: Yale University Press; \r\nBulgarelli, M. (1997). Wolfgang Lotz e la storiografia dell’architettura del Rinascimento. In W. Lotz, L’architettura del Rinascimento (pp. 223-228). Milan: Electa;\r\nThoenes, C. (2013). Wachstum: die Bibliotheca Hertziana unter Wolfgang Lotz (1963-1980). In S. Ebert-Schifferer (Ed.), 100 Jahre Bibliotheca Hertziana – Max-Planck-Institut für Kunstgeschichte. Die Geschichte des Instituts 1913-2013 (pp. 192-199). Munich: Hirmer;\r\nLauterbach, I. (2015). Der Central Collecting Point in München. Berlin, Munchen: Deutscher Kunstverlagad;", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564239176')
# rdflib.term.Literal('           G. Fiocco', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                   F. Codagnato', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('fresco painting', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580502181')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q614082')
# rdflib.term.Literal('                     W. Bornheim-Schilling', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             Ex convento di Santa Cristina, second floor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             L. Dodd', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Adolph Goldschmidt', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           Ch.L. Frommel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657455570')
# rdflib.term.Literal('      Germany')
# rdflib.term.Literal('         Baroque', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Giacomo Barozzi da Vignola', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('               Renaissance', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           archive document', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     V. Branca', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580069971')
# rdflib.term.Literal('Bibliography; Archivio di Adolfo Venturi", a cura di G. Agosti, Pisa, Scuola Normale Superiore, 1990-1995, voll. 4 (1 "Introduzione al carteggio 1876-1908", 1990; 2 "Elenco dei corrispondenti", 1991; 3 "Introduzione al carteggio 1909-1941", 1992; 4 "Incontri venturiani: 22 gennaio, 11 giugno 1991", 1995)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('The collection is relevant for Venetian Studies and Provenance Research\r\n\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       ISAD(G)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576268038')
# rdflib.term.Literal('            Werner Weisbach', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574545652')
# rdflib.term.Literal('                         C. Borchers', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q964573')
# rdflib.term.Literal('The scholar’s book collection of roughly 5,000 volumes has been absorbed into the Zeri Library and is currently open to consultation.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           G. Fiensch', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q36180')
# rdflib.term.Literal('             catalogue', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q580807')
# rdflib.term.Literal('Luisa Vertova (1921-) studied art history and archaeology at Florence university in the early 1940s. After graduation, she worked as translator, contributor and editor. At the end of the war, through mutual friends, Vertova met Bernard Berenson who invited her to work with him as assistant arranging also his important photographic collection kept in Settignano, Villa I Tatti. She worked alongside Nicky Mariano and Berenson till his death in 1959, even after marrying the art historian Benedict Nicolson (1914-1978) and moving to London. By the early 1960s, after her divorce from Nicolson, she started working as Old Master Paintings and Drawings  Specialist at Christie’s International auction house. Between early 1960s and mid-1980s she has been adviser for most auctions organized by Christie’s italian offices in Milan, Florence, Rome. In addition to personal research interests, such as studies on Lombard painters in Seventeenth Century, she undertook important projects as editor of several editions of Berenson’s writings and Caravaggism in Europe by Nicolson. In later years, the scholar returned to Florence where she still lives.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                  P. Cunningham', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Nachlass Otto Lehmann-Brockhaus', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Benedict Nicolson', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Via Giuseppe Giusti 44, 50121', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1888', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('architecture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     C.G. Bowen', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q63425235')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1263')
# rdflib.term.Literal("Series I. Notebooks, 1924-1985 67.0 notebook(s)\r\nThe notebooks are travel diaries that record in detail works seen in public and private collections, and contain alphabetical lists of paintings, artists, and monuments. These notebooks record Waterhouse's travels in the United Kingdom, the United States, and Europe, especially Italy, and the artworks seen there.\r\n\r\nSeries II. Research Files, 1801-1987 25.0 box(es)\r\nThe research files contain notes, draft catalogues and bibliographies, lectures, correspondence, photographs, notebooks, annotated books and printed catalogues (mainly of British collections). The subject matter covered includes British country houses, Reynolds, Gainsborough, El Greco, Italy and Italian Baroque art. Correspondents include art historians, curators, collectors and dealers. Photographic material includes images of paintings and photo essays on the architecture of southern Italy. Two boxes contain photocopies of diaries possibly those kept by Sir Charles Eastlake, former director of the National Gallery. The few personal items include photostats and microfiche of Waterhouse family photograph albums.", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1891')
# rdflib.term.Literal('Julian Kliemann')
# rdflib.term.Literal('The fonds consist of some 18.000 items (letters, manuscripts, notes and notebooks)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                          K. Berger', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('classics', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('               Rome')
# rdflib.term.Literal('            E.P.T. Firenze', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q131647')
# rdflib.term.Literal('Christian art', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('     education', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Documents are grouped in folders by subject and alphabetical / chronological order\r\n\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            L. Dussler', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           M. Fischel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('      aesthetics', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576058405')
# rdflib.term.Literal('              albumen print', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('  ancient art', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q30')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564415604')
# rdflib.term.Literal('        Giovanni Battista Moroni', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('available by appointment', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574510872')
# rdflib.term.Literal('               Leonardo da Vinci', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559132053777')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659864094')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q490')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559568562249')
# rdflib.term.Literal('     document', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q210081')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657322352')
# rdflib.term.Literal('       Vittore Carpaccio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           A. Fuller', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('    Julius von Schlosser', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('partially restricted, available by request', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            P.M. Douan', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('4 boxes, the fund consists 1894 items', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('    window glass', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q724192')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564634678')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658679493')
# rdflib.term.Literal('               photograph', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659597595')
# rdflib.term.Literal('Lotz, W. (1955). Die ovalen Kirchenräume des Cinquecento. Römisches Jahrbuch für Kunstgeschichte, 7, 7-98; \r\nLotz, W. (1958). Redefinitions of Style: Architecture in the Later 16th Century. College Art Journal, 17, 129-139; \r\nLotz, W. (1969). Die spanische Treppe: Architektur als Mittel der Diplomatie. Römisches Jahrbuch für Kunstgeschichte, 12, 39-94; \r\nLotz, W., & Heydenreich, L.H. (1974). Architecture in Italy 1400-1600. Harmondsworth: Penguin Books; \r\nLotz, W. (1977). Studies in Italian Renaissance Architecture. Cambridge: MIT press; \r\nLotz, W. (1995). Architecture in Italy 1500-1600, New Haven: Yale University Press;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559562843627')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q8242')
# rdflib.term.Literal('                  transparency', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1644597')
# rdflib.term.Literal('             D. Donald', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574678841')
# rdflib.term.Literal('    literature', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657971583')
# rdflib.term.Literal('1983', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579345500')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564627543')
# rdflib.term.Literal('                  W.G. Constable', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('168 boxes (ca. 70 lin. ft.)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Ted Koehler', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('fondazionezeri.info@unibo.it', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q6936496')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q4868805')
# rdflib.term.Literal('              C. De Azevedo', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                 St. Burger', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659653206')
# rdflib.term.Literal('                 church building', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       P. Pellizzari', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3949')
# rdflib.term.Literal('     Renaissance', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                          A. Bertini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('          Hilton Kramer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Federico Zeri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://www.sns.it/')
# rdflib.term.Literal('                           15th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('KHI-LUD', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659814126')
# rdflib.term.Literal('Ernst Steinmann was born on September 4th, 1866 in Jördenstorf (Mecklenburg-Western Pomerania), son of protestant pastor Adolf Steinmann. Since 1887 he studied theology and art history in Tübingen, Rostock and Leipzig; among his teachers were Johannes Adolph Overbeck (1826-1895) and particularly Anton Springer (1825-1891). In 1891 Steinmann became scientific associate at the Archeological Institute in Leipzig, completing his dissertation on inscriptions and wall paintings in medieval churches in 1892. Since late 1893 Steinmann worked in Italy predominately in Rome and Florence where he dedicated his studies to Renaissance art, especially to Michelangelo who became his lifelong pivotal artist. Steinmann’s writings were often criticized for their wistful and lyrical style, but his publications had notable success also because of the outstanding quality of the photographic illustrations, many of them produced by Domenico Anderson (1854-1938). After his marriage with Olga von Gerstfeld (1866-1910) in June 1901, Steinmann became director of the Art Museum in Schwerin in 1903. He resigned the position in 1911 and moved to Rome. Since 1894 Steinmann was closely related to Henriette Hertz (1846-1913) and encouraged her early to build up a scientific library for scholarship in Art History in the Palazzo Zuccari in Rome. In 1913 Steinmann became the founding director of the Bibliotheca Hertziana which, after long negotiations, became one of the first institutes of the newly founded Kaiser-Wilhelm-Gesellschaft (since 1948: Max-Planck Society). During the First World War Steinmann lived in Germany and continued working on his study on Napoleon’s “Kunstraub”, completely published only in 2007. At the end of 1919 he returned to Rome to reenter his position as director of the Bibliotheca Hertziana. Faced with declining health and the coming into power of the Nazi regime in Germany, Steinmann retired in 1934 naming Leo Bruhns (1884-1957) to become his successor. Though the scientific relevance of his own studies is not much valued today, Steinmann played a significant role in the development of studies in Italian Renaissance and Barock art. As director of the Bibliotheca Hertziana he promoted important research projects and supported the early career of eminent scholars such as Richard Krautheimer (1897-1994) and Rudolf Wittkower (1901-1971). Steinmann died on November 24th, 1934 in Basel. His burial place is in Rome. ', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q9296305')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q7814')
# rdflib.term.Literal('              W.S.A. Dale', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Hungarian engineer and art historian. He trained as an engineer and became a senior manager in the Hungarian railways. Following a two-year study trip to Italy (1876–8), he resigned his post and embarked upon a new career as an art historian. He visited Paris and London and in 1880 settled in Stuttgart.\r\nFabriczy devoted the greater part of his life to the study of Italian, and in particular Florentine, Renaissance art. In 1892 he published a major study of the life and work of the Florentine architect and engineer Filippo Brunelleschi. At the same time, after research in the Biblioteca Nazionale of Florence, most notably on 16th-century documents (the Codice Strozziano and Codice Petrei) containing notes on Florentine artists of considerable art historical value, he published the so-called Libro di Antonio Billi (1891; see Billi, Antonio) and the Codice dell’Anonimo Magliabechiano (1893). Fabriczy’s research had been undertaken in consultation with the Florentine art historian Gaetano Milanesi, but he was careful to correct the German scholar Karl Frey, whose own interpretation of the same manuscripts (1892) did not always agree with Fabriczy’s, when Frey wrote that Milanesi had helped Fabriczy to discover the Codices. In the later 1890s Fabriczy began to collaborate with Wilhelm Bode on a revised edition of Jakob Burckhardt’s guidebook to Italian art, Der Cicerone (1855). In 1903 Fabriczy published his study of Italian Renaissance medals, a work which, by bringing together the results of scholarship to date and combining the numismatic approach with an appreciation of medals as works of art, may rank as his most original and perhaps most valuable contribution to art historical study. (https://www.oxfordartonline.com)\r\n\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('               Otto Lehmann-Brockhaus', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Raphael', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Federico Zeri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659884653')
# rdflib.term.Literal('                   K. Clark', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('2003', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659683287')
# rdflib.term.Literal('        Jacopo Bassano', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('2020-10-13T18:41:49.534000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3647585')
# rdflib.term.Literal('             15th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2528876')
# rdflib.term.Literal('                 J.S. Byrne', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Ernst Barlach', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q60643992')
# rdflib.term.Literal('Warburg Institute', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('        Creative Commons Attribution-NonCommercial', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q7882150')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579908224')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q429811')
# rdflib.term.URIRef('https://w3id.org/artchives/mhatam-at-getty-dot-edu')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659609953')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q37030')
# rdflib.term.Literal('Rembrandt', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1257962')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574607915')
# rdflib.term.Literal('     Germany')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q195660')
# rdflib.term.Literal('             manuscript', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559843162470')
# rdflib.term.Literal('   Baroque', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559137162136')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559842830267')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559563822025')
# rdflib.term.Literal('                            K.G. Bernheimer; J.A. Bernstein;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('The photo library is divided into sections according to the different typologies of art objects documented in the photos. Besides its rich Italian painting collection (150,000 photographs), the archive contains sizable core collections covering Italian sculpture (17,000), Italian and European Still Life (14,400 photos), "Non-Italian art" (), Archaeology (5,300), Architecture (8,800), Drawings (12,700), the Applied arts (18,000 photos), Miniatures (5,500), Fakes ().  Inside the boxes photos are kept inside folders bearing the artists\' names. Phototypes are 100% positives, for the most part black and white prints on paper: gelatin silver prints, albumen prints, carbon prints, collotypes, photogravures, with a smaller section of color prints and transparencies.\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q20103')
# rdflib.term.Literal('1617', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('                 Burlington Magazine', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('The origin of the collection goes back to the first years of study and to the first research projects produced by Warburg in Florence together with KHI Director Heinrich Brockhaus and continued, with numerous interruptions, until 1927.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              art historian')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559654341162')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q16139')
# rdflib.term.Literal('World War I', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q19997518')
# rdflib.term.Literal('                C. Cahn-Bronner', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('    Annette Michelson', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659962194')
# rdflib.term.Literal('University of Bonn', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Adlib Software\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('         photograph', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            Lorenzo Ghiberti', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579900325')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q57414113')
# rdflib.term.Literal('           Salvator Rosa', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1557412703715')
# rdflib.term.Literal('       New York University Institute of Fine Arts', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579526580')
# rdflib.term.Literal('              E. De Kolb', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q50914856')
# rdflib.term.Literal('                     T.A. von Borsig', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Archivio Luisa Vertova', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/collectionnachlass-ernst-steinmann')
# rdflib.term.Literal('                      sculpture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Hans Sedlmayr', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Creative Commons Attribution-NonCommercial', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            J.A. Emmens', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal("       Titian's school", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              U. Desportes', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('               Pietro Bracci', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q3624153')
# rdflib.term.Literal('                Callway Verlag', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('  architecture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('33.0 linear feet (55 boxes)', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660096975')
# rdflib.term.Literal('                  G. Coor', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658474138')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q5')
# rdflib.term.Literal('                 W.W. Busam', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('         altarpiece', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('2020-10-25T11:41:53.678000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.Literal(" The Leo Steinberg Research Papers consist of research notes, correspondence relating to his lectures and essays, papers written by his students, several versions of some of his essays, an abandoned dissertation project, and many of his notebooks from courses he took at the Institute of Fine Arts, New York University. The archive reflects Steinberg's career as an art critic, lecturer and teacher from ca. 1945-ca.1996. The research notes and course notebooks give a clear picture of Steinberg's fields of interest, as well as his association with many distinguished art historians.\r\nIncluded are Steinberg's unpublished research on Borromini, his work on Rodin and Titian in the form of notes, photographs, lectures in typescript with notes; a few essays by others; his dissertation on Borromini, and professional correspondence such as with Rudolf Wittkower about Borromini. \r\n\r\n", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('        typescript', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1936', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('            L. Döry', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658295366')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660143965')
# rdflib.term.Literal('    sculpture', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574671369')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580339221')
# rdflib.term.Literal('               Florence', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q191067')
# rdflib.term.Literal('    Jacob Burckhardt', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('      17th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q49210')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q762')
# rdflib.term.Literal("Fahy, E. (1976). Some Followers of Domenico Ghirlandaio. New York: Garland; \r\nFahy, E. (1973). The Wrightsman Pictures. New York: Metropolitan Museum of Art; \r\nFahy, E. (1979). The Legacy of Leonardo: Italian Renaissance Paintings from Leningrad. Washington, DC: National Gallery of Art; \r\nFahy, E. (1983). Metropolitan Flowers. New York: Abrams; \r\nFahy, E. (2000). L' Archivio storico fotografico di Stefano Bardini: Dipinti, disegni, miniature, stampe. Firenze: Bruschi;", datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           M. Fischer', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     P. Brown', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           L. Frede', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559657647977')
# rdflib.term.Literal('                      18th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1303856')
# rdflib.term.Literal('            W. Drost', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660199549')
# rdflib.term.Literal('                         H. Biermann', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Ernst Steinmann', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                         P. Boenders', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           art critic', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                J.R. Chanter', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     L. Boynton', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# ...
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659838667')
# rdflib.term.Literal('                  E. Coturri', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1598618937689')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559750451483')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559574589113')
# rdflib.term.Literal('                     A.M. Boúnoús', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q208125')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q345605')
# rdflib.term.Literal('      16th century', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           M. Fedder', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Egypt', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Ursula Lehmann-Brockhaus', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('bestiary', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1940', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q9440')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580838680')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1465805')
# rdflib.term.Literal('Born in Berlin on November 11th, 1949 from the famous artist Carl-Heinz Kliemann (Berlin, 1924-2016), he completed his university studies first in Berlin and then in Heidelberg in 1976, with a dissertation entitled "Politische und Humanistische Ideen der Medici in der Villa Poggio a Caiano. Untersuchungen zu den Frescken der Sala Grande". He subsequently obtained numerous research assignments at Villa I Tatti (The Harvard University Center for Italian Renaissance Studies), at the universities of Munich and Münster, at the Bibliotheca Hertziana in Rome, spending a period as Visiting Scholar at the Getty Research Institute in California. He was professor at the Universities of Heidelberg and Münster. He conducted innovative research in iconographic studies, making use of an uncommon expertise on sources and artistic historiography of the sixteenth and seventeenth centuries. He left important contributions on Giorgio Vasari historiographer and painter, Federico Zuccari and David Bailly. He died at the age of 65 on July 6th, 2015.\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q2013867')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564326021')
# rdflib.term.Literal('          Antonio Vivarini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580869265')
# rdflib.term.Literal('The fund consists of 463 items including archival research on Antonio e Giovanni da Sangallo, Michelozzo, Michelangelo, Amico Aspertini ', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('               Francesco Hayez', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                F. Calegari', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q63078')
# rdflib.term.Literal('Ulrich Middeldorf (1901-1983): born in Strassfurt in 1901, he studied art history at the Universities of Giessen, Munich and Berlin. From 1926 to 1935 he took care of the photo library of the Kunsthistorisches Institut in Florenz, of which he was then director (1953-68), after having taught (1935-53) at the University of Chicago where he was conservator of the sculpture department of the Art Institute of Chicago. From 1971 to 1975 he was head of the Longhi Foundation. He has dealt mainly with Italian Renaissance art. M. studied art history in Giessen - Christian Rauch, in Munich - Heinrich Wölfflin and finally in Berlin with - Adolf Goldschmidt, where he received his doctorate in 1924 with the dissertation "Die thüring.-sächs. Skulptur 1250-1350" (ungedr.) has been. 1925-26 he worked at the German Kunsthistorisches Institut in Florence as a scholarship holder, afterwards he lived there until 1935 as a freelance artist. In addition to publications on the artistic interrelations between Italy and Northern Europe, the architecture of the Trecento and the sculpture of the Four- and Cinquecento, he acquired in this decade, the mental armor for his further activity.\r\nMiddeldorf moved to the United States in 1935, where he served as Professor and Chairman of the Art Department at the University of Chicago, as well as a permanent consultant and initiator of the city\'s museum and exhibition space. In the 17 years of his activity there, where he also belonged to the editors of "Art Bulletin" and "Art in America" \u200b\u200bas well as the board of the "Renaissance Society", he understood himself as a mediator of the European, in particular | Italian art and culture. With numerous reviews he taught in politically difficult time the American. Audience on priorities of art historical research in Europe. At the same time he published a wealth of new attributions and interpretations of works of art of Italian sculpture, graphic art and applied art. In 1944 and 1945 his works appeared on Raphael\'s drawings and on the Italian medal art of the 15th-18th centuries. In 1953, M. was appointed director of the German Kunsthistorisches Institut in Florence, orphaned in wartime and post-war years, where he devoted himself to the task of reviving it according to its international significance. In his term of office, which lasted until 1968, he increased the library and photographers\' holdings three-fold to 90,000 volumes and 250,000 photographs, which he was able to accommodate in a new building, thus significantly improving the working conditions at this institute. M. was particularly popular with advice for his colleagues to the stars, so that a significant part of his scientific achievements of these years can be found in the work of third parties. After the end of his directorate M. resumed his publishing activities increasingly.                            \r\nGerman-American art historian who specialized in the areas of sculpture, bronzes, and the applied arts. The bulk of the collection consists of Middeldorf\'s research files: clippings and bibliographic notations about the arts, particularly sculpture, drawings, Renaissance medals, and applied arts such as costumes, textiles, furniture, and metalwork. \r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('KHI - C v F', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                          R. Bertos', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                            F.A. Bernett;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1890', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('              Pompeo Molmenti', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1177671')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q214493')
# rdflib.term.Literal('                    B. Cherubini', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                         R. Bondi', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579827876')
# rdflib.term.Literal('              Isabella Stewart Gardner Museum', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Nachlass Kurt Badt', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('             Ulrich Middeldorf', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                         Bona di Baviera', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Tumidei, S. (2011). Studi sulla pittura in Emilia e in Romagna: Da Melozzo a Federico Zuccari 1987-2008. Trento: Temi; \r\nTumidei, S. (2004). La nobile villeggiatura : i Rasponi a Palazzo San Giacomo di Russi. Ravenna: Longo;\r\nTumidei, S., Bacchi, A. & Massari, S. (Eds.). (2016). Antonio Trentanove e la scultura del Settecento in Romagna. Bologna, Fondazione Federico Zeri; \r\nPaolucci, A., Prati, L. & Tumidei, S. (2005). Marco Palmezzano: Il Rinascimento nelle Romagne. Cinisello Balsamo: Silvana;', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q41616785')
# rdflib.term.Literal('type of artwork', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1854', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660205597')
# rdflib.term.Literal('    John Canaday', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('       Georg Graf Vitzhum', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1034868')
# rdflib.term.URIRef('https://w3id.org/artchives/artHistorianBibliography')
# rdflib.term.Literal('        Julius S. Held', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('     ISAD', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('              Online Archive of California', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1700-01-01T00:00:00+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q16172')
# rdflib.term.Literal('Documents are grouped by subject and themes related to publications.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579617165')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1598611494990')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658478474')
# rdflib.term.Literal('    Orsanmichele', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559568493236')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659557120')
# rdflib.term.Literal('1921', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('                     H.N.A. Brigstocke', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('            H. Dotterweich', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('art history', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('the fund consinsts in 220 items (120 archival units)\r\n', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('           Auguste Rodin', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Federico Zuccari', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580487059')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559652671430')
# rdflib.term.Literal('1947', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('NONE ', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q683814')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559576187623')
# rdflib.term.Literal('           John Walsh', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                  H. Coing', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                  photographic print', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q277466')
# rdflib.term.Literal('55 folders', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q517')
# rdflib.term.Literal('2020-10-13T12:34:18.666000+00:00', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#dateTime'))
# rdflib.term.Literal('                     K. Brookes', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('1876', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#gYear'))
# rdflib.term.Literal('            Christoph Luitpold Frommel', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559580526058')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559579543486')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559660161765')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659828661')
# rdflib.term.Literal('       Rudolf Wittkower', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q1055')
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q157575')
# rdflib.term.Literal(' \tSeries I. Writings, 1932-1995\r\n\tSeries II. Various Research Projects (unpublished), 1968-1993\r\n\tSeries III. Lectures, 1931-1990\r\n\tSeries IV. Harvard Courses, 1960, 1968-1978\r\n\tSeries V. Harvard Seminars, 1947-1979\r\n\tSeries VI. Floor Mosaics, n.d.\r\n\tSeries VII. Cleveland Marbles, 1966-1979, n.d.\r\n\tSeries VIII. Various Topics (research files and correspondence), , 1962-1994 n.d.\r\n\tSeries IX. Various Matters (professional activities and other writings), 1942-1943, 1956, 1961-1986\r\n\tSeries X. Photographs, 1937-1991, n.d.\r\n\tSeries XI. Slides, n.d.\r\n\tSeries XII. Negatives, 1937, 1943, n.d.', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Forl�', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('Bennington', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('http://www.wikidata.org/entity/Q28823')
# rdflib.term.Literal('              archive document', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('                     I.M. Botto', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559658126575')
# rdflib.term.Literal('archival description')
# rdflib.term.Literal('         Palma Vecchio', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('history of Europe', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('   Paul Frankl', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1599064240072')
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559659633394')
# rdflib.term.Literal('                  art historian')
# rdflib.term.Literal('Wilhelm V�ge', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.Literal('      DACS', datatype=rdflib.term.URIRef('http://www.w3.org/2001/XMLSchema#string'))
# rdflib.term.URIRef('https://w3id.org/artchives/MD1559564503981')

# %% [markdown]
# Look at the results: RDFlib classifies URIs as `rdflib.URIRef` and strings as `rdflib.Literal`, which are two of the aforementioned terms that RDFlib handles. We can reuse such methods to query data in more precisely ways.

# %% [markdown]
# ### 2.5 Replace variables with real values
#
# When iterating over triples, we can replace placeholders with real values.
# For instance, we can get **all the triples that have as subject the URI identifying Federico Zeri**(`http://www.wikidata.org/entity/Q1089074`)

# %%
from rdflib import URIRef, Literal
# all the properties and objects having Federico Zeri as subject
for s, p, o, c in g.quads():
    if s == URIRef('http://www.wikidata.org/entity/Q1089074'): # the URI representing Federico Zeri
        print(p, o)
# Out:
# http://www.w3.org/2000/01/rdf-schema#label    Federico Zeri
# http://www.w3.org/2000/01/rdf-schema#label               Federico Zeri
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q242942
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q1891
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q38
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q537874
# http://www.w3.org/2000/01/rdf-schema#label Federico Zeri
# http://www.w3.org/2000/01/rdf-schema#label Federico Zeri
# http://www.w3.org/2000/01/rdf-schema#label Federico Zeri
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q5092
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q359047
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q807815
# http://purl.org/dc/terms/description Federico Zeri was born in Rome in 1921 and died on October 5, 1998 at his villa in Mentana. Eccentric scholar and art historian, is considered one of the greatest connoisseurs of the twentieth century.
# When at the University of Rome in the early 1940s, Zeri followed the courses of Pietro Toesca, under whom he graduated in 1945. Zeri's unconventional approach to the discipline made an early appearance in his degree thesis, where the subject was Jacopino del Conte, a painter of Roman Mannerism to whom little importance was given at the time. Zeri would often choose obscure viewpoints from which to ask innovative questions on the great themes in art history.
# It was Toesca who introduced him to Bernard Berenson, a figure who deeply fascinated the young Zeri, who would later dedicate to him his book on the Master of the Barberini Panels. At the end of the war Zeri made the acquaintance of Giuliano Briganti, Mario Praz, as well as Roberto Longhi, a maestro with a strong and charismatic personality with whom he was to have a quarrelsome and sometimes competitive relationship.
# He took up employment on the fine arts committee of the Ministry for Cultural Heritage, and in 1948 was appointed director of the Galleria Spada in Rome. He left this position at the beginning of the 1950s after publishing a fundamental catalog of the collection, published by Sansoni in 1954.
# From then on, Zeri's career was that of an independent art historian. His interest in rediscovering minor areas of art production led to a philological and historical recuperation of forgotten artists, lost pictorial series, and an entire figurative geography overlooked by scholars.  His first trips to Paris and London between 1947 and 1948 brought him in contact with leading figures in international connoisseurship like Philip Pouncey, Denis Mahon, John Pope-Hennessy and Frederick Antal. Zeri later claimed to owe a great deal to Antal for his interest in the relations between art and society.
# He combined his talent as a connoisseur with a close network of relations which brought him into contact with the leading collectors and antiquarians of the time, including Vittorio Cini, J. Paul Getty, Alessandro Contini Bonacossi and Daniel Wildenstein. Of great significance were his relations with the United States: as a visiting professor at Harvard University in Cambridge (Mass.) and New York's Columbia University, as well as being instrumental in setting up the Getty Museum in Los Angeles. He curated the repertory of Italian paintings in public American collections (Census of Pre-Nineteenth Century Italian Paintings in North American Public Collections, 1972), as well as the catalogues of the Walters Art Gallery in Baltimore (1976), and the four volumes of the catalogue of Italian paintings of the Metropolitan Museum of Art in New York (1971, 1973, 1980, 1986).
# From 1975 to 1984 he was the only European trustee of the J. Paul Getty Museum.
# In 1993 he was appointed deputy chairman of the national council for the cultural heritage. In April 1997, he was admitted as a member of the Académie des Beaux-Arts. On February 6th, 1998 he was awarded an honorary degree by the University of Bologna.
#
#
#
#
# http://www.wikidata.org/prop/direct/P106 https://w3id.org/artchives/MD1557321803308
# http://www.wikidata.org/prop/direct/P800 https://w3id.org/artchives/artHistorianBibliography
# http://www.wikidata.org/prop/direct/P570 1998
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q65
# http://www.w3.org/1999/02/22-rdf-syntax-ns#type http://www.wikidata.org/entity/Q5
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q215037
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q210081
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q220
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q13371
# http://www.wikidata.org/prop/direct/P27 http://www.wikidata.org/entity/Q38
# http://www.wikidata.org/prop/direct/P106 http://www.wikidata.org/entity/Q1126160
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q1361667
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q981971
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q170027
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q49088
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q30
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q90
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q3769356
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q2538308
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q60
# http://www.w3.org/2000/01/rdf-schema#label          Federico Zeri
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q723358
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q3757699
# http://www.wikidata.org/prop/direct/P921 http://www.wikidata.org/entity/Q3705445
# http://www.wikidata.org/prop/direct/P569 1921

# %% [markdown]
# Now, imagine we want only the object of a specific property, for instance the biography of Federico Zeri, which is the object of the property `http://purl.org/dc/terms/description`. To get that, we need to specify the triple pattern as follows:

# %%
for s, p, o, c in g.quads():
    if s == URIRef('http://www.wikidata.org/entity/Q1089074') \
    and p == URIRef('http://purl.org/dc/terms/description'): # the URI representing Federico Zeri
        print(o)
# Out:
# Federico Zeri was born in Rome in 1921 and died on October 5, 1998 at his villa in Mentana. Eccentric scholar and art historian, is considered one of the greatest connoisseurs of the twentieth century.
# When at the University of Rome in the early 1940s, Zeri followed the courses of Pietro Toesca, under whom he graduated in 1945. Zeri's unconventional approach to the discipline made an early appearance in his degree thesis, where the subject was Jacopino del Conte, a painter of Roman Mannerism to whom little importance was given at the time. Zeri would often choose obscure viewpoints from which to ask innovative questions on the great themes in art history.
# It was Toesca who introduced him to Bernard Berenson, a figure who deeply fascinated the young Zeri, who would later dedicate to him his book on the Master of the Barberini Panels. At the end of the war Zeri made the acquaintance of Giuliano Briganti, Mario Praz, as well as Roberto Longhi, a maestro with a strong and charismatic personality with whom he was to have a quarrelsome and sometimes competitive relationship.
# He took up employment on the fine arts committee of the Ministry for Cultural Heritage, and in 1948 was appointed director of the Galleria Spada in Rome. He left this position at the beginning of the 1950s after publishing a fundamental catalog of the collection, published by Sansoni in 1954.
# From then on, Zeri's career was that of an independent art historian. His interest in rediscovering minor areas of art production led to a philological and historical recuperation of forgotten artists, lost pictorial series, and an entire figurative geography overlooked by scholars.  His first trips to Paris and London between 1947 and 1948 brought him in contact with leading figures in international connoisseurship like Philip Pouncey, Denis Mahon, John Pope-Hennessy and Frederick Antal. Zeri later claimed to owe a great deal to Antal for his interest in the relations between art and society.
# He combined his talent as a connoisseur with a close network of relations which brought him into contact with the leading collectors and antiquarians of the time, including Vittorio Cini, J. Paul Getty, Alessandro Contini Bonacossi and Daniel Wildenstein. Of great significance were his relations with the United States: as a visiting professor at Harvard University in Cambridge (Mass.) and New York's Columbia University, as well as being instrumental in setting up the Getty Museum in Los Angeles. He curated the repertory of Italian paintings in public American collections (Census of Pre-Nineteenth Century Italian Paintings in North American Public Collections, 1972), as well as the catalogues of the Walters Art Gallery in Baltimore (1976), and the four volumes of the catalogue of Italian paintings of the Metropolitan Museum of Art in New York (1971, 1973, 1980, 1986).
# From 1975 to 1984 he was the only European trustee of the J. Paul Getty Museum.
# In 1993 he was appointed deputy chairman of the national council for the cultural heritage. In April 1997, he was admitted as a member of the Académie des Beaux-Arts. On February 6th, 1998 he was awarded an honorary degree by the University of Bologna.

# %% [markdown]
# RDFlib offers competing and **shorter methods to access triples** in the graphs.
#
#  * Instead of iterating over all the quads we can iterate over all the **triples** belonging to any graph (basically, we ignore the fourth variable `c`)
#  * We use the *placeholder* **None** in the lookup triple pattern.
#
# The method that allows us to iterate over all triples is called `triples()` and it accepts a tuple `()` including three placeholders, respectively for the subject, the predicate, and the object. When one or more of the terms in the triple pattern are not known (e.g. in our case we don't know the *object* of the property `dcterms:description`) we use as placeholder the term `None`. For instance:

# %%
for s, p, o in g.triples((URIRef('http://www.wikidata.org/entity/Q1089074'), URIRef('http://purl.org/dc/terms/description'), None )):
    print(o)
# Out:
# Federico Zeri was born in Rome in 1921 and died on October 5, 1998 at his villa in Mentana. Eccentric scholar and art historian, is considered one of the greatest connoisseurs of the twentieth century.
# When at the University of Rome in the early 1940s, Zeri followed the courses of Pietro Toesca, under whom he graduated in 1945. Zeri's unconventional approach to the discipline made an early appearance in his degree thesis, where the subject was Jacopino del Conte, a painter of Roman Mannerism to whom little importance was given at the time. Zeri would often choose obscure viewpoints from which to ask innovative questions on the great themes in art history.
# It was Toesca who introduced him to Bernard Berenson, a figure who deeply fascinated the young Zeri, who would later dedicate to him his book on the Master of the Barberini Panels. At the end of the war Zeri made the acquaintance of Giuliano Briganti, Mario Praz, as well as Roberto Longhi, a maestro with a strong and charismatic personality with whom he was to have a quarrelsome and sometimes competitive relationship.
# He took up employment on the fine arts committee of the Ministry for Cultural Heritage, and in 1948 was appointed director of the Galleria Spada in Rome. He left this position at the beginning of the 1950s after publishing a fundamental catalog of the collection, published by Sansoni in 1954.
# From then on, Zeri's career was that of an independent art historian. His interest in rediscovering minor areas of art production led to a philological and historical recuperation of forgotten artists, lost pictorial series, and an entire figurative geography overlooked by scholars.  His first trips to Paris and London between 1947 and 1948 brought him in contact with leading figures in international connoisseurship like Philip Pouncey, Denis Mahon, John Pope-Hennessy and Frederick Antal. Zeri later claimed to owe a great deal to Antal for his interest in the relations between art and society.
# He combined his talent as a connoisseur with a close network of relations which brought him into contact with the leading collectors and antiquarians of the time, including Vittorio Cini, J. Paul Getty, Alessandro Contini Bonacossi and Daniel Wildenstein. Of great significance were his relations with the United States: as a visiting professor at Harvard University in Cambridge (Mass.) and New York's Columbia University, as well as being instrumental in setting up the Getty Museum in Los Angeles. He curated the repertory of Italian paintings in public American collections (Census of Pre-Nineteenth Century Italian Paintings in North American Public Collections, 1972), as well as the catalogues of the Walters Art Gallery in Baltimore (1976), and the four volumes of the catalogue of Italian paintings of the Metropolitan Museum of Art in New York (1971, 1973, 1980, 1986).
# From 1975 to 1984 he was the only European trustee of the J. Paul Getty Museum.
# In 1993 he was appointed deputy chairman of the national council for the cultural heritage. In April 1997, he was admitted as a member of the Académie des Beaux-Arts. On February 6th, 1998 he was awarded an honorary degree by the University of Bologna.

# %% [markdown]
# ### 2.6 Namespaces
#
# As you can see the triple pattern can be very long if we have one or more URIs to specify.
#
# RDFlib provides means to shorten URIs by using their **namespace** followed by the short ID of the term,. For instance:
#
# ```
# http://purl.org/dc/terms/ -> DCTERMS
# http://purl.org/dc/terms/description -> DCTERMS.description
# ```
#
# Moreover, RDFlib has built-in namespaces for the most common vocabularies, such as RDF, RDFS, FOAF, and DCTERMS (our case!). Therefore we can shorten the prior code in a more readable way as follows.

# %%
from rdflib.namespace import DCTERMS

zeri = URIRef('http://www.wikidata.org/entity/Q1089074')
for s, p, o in g.triples((zeri, DCTERMS.description, None)):
    print(o)
# Out:
# Federico Zeri was born in Rome in 1921 and died on October 5, 1998 at his villa in Mentana. Eccentric scholar and art historian, is considered one of the greatest connoisseurs of the twentieth century.
# When at the University of Rome in the early 1940s, Zeri followed the courses of Pietro Toesca, under whom he graduated in 1945. Zeri's unconventional approach to the discipline made an early appearance in his degree thesis, where the subject was Jacopino del Conte, a painter of Roman Mannerism to whom little importance was given at the time. Zeri would often choose obscure viewpoints from which to ask innovative questions on the great themes in art history.
# It was Toesca who introduced him to Bernard Berenson, a figure who deeply fascinated the young Zeri, who would later dedicate to him his book on the Master of the Barberini Panels. At the end of the war Zeri made the acquaintance of Giuliano Briganti, Mario Praz, as well as Roberto Longhi, a maestro with a strong and charismatic personality with whom he was to have a quarrelsome and sometimes competitive relationship.
# He took up employment on the fine arts committee of the Ministry for Cultural Heritage, and in 1948 was appointed director of the Galleria Spada in Rome. He left this position at the beginning of the 1950s after publishing a fundamental catalog of the collection, published by Sansoni in 1954.
# From then on, Zeri's career was that of an independent art historian. His interest in rediscovering minor areas of art production led to a philological and historical recuperation of forgotten artists, lost pictorial series, and an entire figurative geography overlooked by scholars.  His first trips to Paris and London between 1947 and 1948 brought him in contact with leading figures in international connoisseurship like Philip Pouncey, Denis Mahon, John Pope-Hennessy and Frederick Antal. Zeri later claimed to owe a great deal to Antal for his interest in the relations between art and society.
# He combined his talent as a connoisseur with a close network of relations which brought him into contact with the leading collectors and antiquarians of the time, including Vittorio Cini, J. Paul Getty, Alessandro Contini Bonacossi and Daniel Wildenstein. Of great significance were his relations with the United States: as a visiting professor at Harvard University in Cambridge (Mass.) and New York's Columbia University, as well as being instrumental in setting up the Getty Museum in Los Angeles. He curated the repertory of Italian paintings in public American collections (Census of Pre-Nineteenth Century Italian Paintings in North American Public Collections, 1972), as well as the catalogues of the Walters Art Gallery in Baltimore (1976), and the four volumes of the catalogue of Italian paintings of the Metropolitan Museum of Art in New York (1971, 1973, 1980, 1986).
# From 1975 to 1984 he was the only European trustee of the J. Paul Getty Museum.
# In 1993 he was appointed deputy chairman of the national council for the cultural heritage. In April 1997, he was admitted as a member of the Académie des Beaux-Arts. On February 6th, 1998 he was awarded an honorary degree by the University of Bologna.

# %% [markdown]
# However, in ARTchives there are also non standard vocabularies, such as:
#
#  * Wikidata classes and individuals, having prefix `http://www.wikidata.org/entity/`
#  * Wikidata properties, having prefix `http://www.wikidata.org/prop/direct/`
#  * ARTchives terms (classes, properties and individuals), having prefix `https://w3id.org/artchives/`
#
# For these cases, RDFlib allows you to specify your own namespaces as follows:

# %%
from rdflib import Namespace

# assign prefixes to namespaces
wd = Namespace("http://www.wikidata.org/entity/") # remember that a prefix matches a URI until the last slash (or hashtag #)
wdt = Namespace("http://www.wikidata.org/prop/direct/")
art = Namespace("https://w3id.org/artchives/")

# %% [markdown]
# For instance, our prior example on Federico Zeri, now looks like the following:

# %%
for s, p, o in g.triples((wd.Q1089074, DCTERMS.description, None)):
    print(o)
# Out:
# Federico Zeri was born in Rome in 1921 and died on October 5, 1998 at his villa in Mentana. Eccentric scholar and art historian, is considered one of the greatest connoisseurs of the twentieth century.
# When at the University of Rome in the early 1940s, Zeri followed the courses of Pietro Toesca, under whom he graduated in 1945. Zeri's unconventional approach to the discipline made an early appearance in his degree thesis, where the subject was Jacopino del Conte, a painter of Roman Mannerism to whom little importance was given at the time. Zeri would often choose obscure viewpoints from which to ask innovative questions on the great themes in art history.
# It was Toesca who introduced him to Bernard Berenson, a figure who deeply fascinated the young Zeri, who would later dedicate to him his book on the Master of the Barberini Panels. At the end of the war Zeri made the acquaintance of Giuliano Briganti, Mario Praz, as well as Roberto Longhi, a maestro with a strong and charismatic personality with whom he was to have a quarrelsome and sometimes competitive relationship.
# He took up employment on the fine arts committee of the Ministry for Cultural Heritage, and in 1948 was appointed director of the Galleria Spada in Rome. He left this position at the beginning of the 1950s after publishing a fundamental catalog of the collection, published by Sansoni in 1954.
# From then on, Zeri's career was that of an independent art historian. His interest in rediscovering minor areas of art production led to a philological and historical recuperation of forgotten artists, lost pictorial series, and an entire figurative geography overlooked by scholars.  His first trips to Paris and London between 1947 and 1948 brought him in contact with leading figures in international connoisseurship like Philip Pouncey, Denis Mahon, John Pope-Hennessy and Frederick Antal. Zeri later claimed to owe a great deal to Antal for his interest in the relations between art and society.
# He combined his talent as a connoisseur with a close network of relations which brought him into contact with the leading collectors and antiquarians of the time, including Vittorio Cini, J. Paul Getty, Alessandro Contini Bonacossi and Daniel Wildenstein. Of great significance were his relations with the United States: as a visiting professor at Harvard University in Cambridge (Mass.) and New York's Columbia University, as well as being instrumental in setting up the Getty Museum in Los Angeles. He curated the repertory of Italian paintings in public American collections (Census of Pre-Nineteenth Century Italian Paintings in North American Public Collections, 1972), as well as the catalogues of the Walters Art Gallery in Baltimore (1976), and the four volumes of the catalogue of Italian paintings of the Metropolitan Museum of Art in New York (1971, 1973, 1980, 1986).
# From 1975 to 1984 he was the only European trustee of the J. Paul Getty Museum.
# In 1993 he was appointed deputy chairman of the national council for the cultural heritage. In April 1997, he was admitted as a member of the Académie des Beaux-Arts. On February 6th, 1998 he was awarded an honorary degree by the University of Bologna.

# %% [markdown]
# ### Exercise (15'): Extract the list of labels of topics related to Federico Zeri
#
# In ARTchives, all the topics (people, genres) studied by a historian are linked to the historian in the following form (in ttl syntax):
#
# `:historian wdt:P921 :topic`.
#
# Every topic is identified by a URI, and is associated to a label (a human-readable string) by means of the property `http://www.w3.org/2000/01/rdf-schema#label`. For instance:
#
# `:topic rdfs:label "topic label"`.
#
# RDFlib allows you to import a built-in namespace called RDFS to recall this predicate faster.
#
# `from rdflib.namespace import RDFS`
#
# Tips:
#
#  * At the beginning of your file import RDFlib and the `Namespace` module
#  * import RDFS along with the built-in namespaces such as DCTERMS
#  * Iterate over the triples having
#
#     * the URI identifying Zeri as subject, and
#     * wdt.P921 as predicate (remember to declare and bind the namespaces to a prefix!)
#  * Iterate over the objects of the prior triple pattern and lookup for a new triple pattern, having now as subject the variable identifying the topic, and as predicate RDFS.label.
#  * print the list

# %%
# solution placeholder

# %% [markdown]
# ## 3. Creating RDF triples
#
# RDFlib allows to create new graphs and to add triples to those.
#
# For instance, in ARTchives there is no information about historians' birth places, birth dates, or sex.
#
# We look at Federico Zeri (`http://www.wikidata.org/entity/Q1089074`) on [Wikidata](https://www.wikidata.org/wiki/Q1089074): he was born in **Rome**, his birthday is **12 August 1921**, and he is **male**.
#
#  * The city of Rome is identified in Wikidata with the URI `https://www.wikidata.org/entity/Q220`.
#  * The birth date is treated as a xsd:date (YYYY-MM-DD)
#  * The sex is identified as a URI as well, but for the sake of the example we treat is a string.
#
# To add this information to the graph, we first need to declare the datatype of objects.

# %%
from rdflib.namespace import XSD
from rdflib import Literal

birthplace = URIRef("https://www.wikidata.org/entity/Q220")
birthdate = Literal('1921-08-12',datatype=XSD.date) # notice the datatype parameter
sex = Literal("male",lang="en") # notice the lang parameter

# %% [markdown]
# Then we need to choose the predicates to which these objects must be linked. We decide to reuse Wikidata predicates:
#
#  * birth place: `http://www.wikidata.org/prop/direct/P19` -> wdt.P19
#  * birth date: `http://www.wikidata.org/prop/direct/P569` -> wdt.P569
#  * sex: `http://www.wikidata.org/prop/direct/P21` -> wdt.P21
#
# **Be aware that URIs of Wikidata web pages differ from the URIs of classes/individuals/predicates there described. Only the last part (after the last slash) applies to both web pages / persistent URIs. **
#
# Lastly, we use the method `add()` to insert a new triple (a tuple) to the graph.

# %%
g.add(( wd.Q1089074, wdt.P19, birthplace ))
g.add(( wd.Q1089074, wdt.P569, birthdate ))
g.add(( wd.Q1089074, wdt.P21, sex ))
# Out:
# <Graph identifier=N53435dcbf1bd4abe842dbd252037b43f (<class 'rdflib.graph.ConjunctiveGraph'>)>

# %% [markdown]
# Now we can double-check if the new data has been correctly added. Let's query our graph for Federico Zeri's birth place, date, and sex.

# %%
check_properties = [wdt.P19, wdt.P569, wdt.P21]

for prop in check_properties:
    for s,p,o in g.triples((wd.Q1089074, prop, None )):
        print(s, prop, o)
# Out:
# http://www.wikidata.org/entity/Q1089074 http://www.wikidata.org/prop/direct/P19 https://www.wikidata.org/entity/Q220
# http://www.wikidata.org/entity/Q1089074 http://www.wikidata.org/prop/direct/P569 1921
# http://www.wikidata.org/entity/Q1089074 http://www.wikidata.org/prop/direct/P569 1921-08-12
# http://www.wikidata.org/entity/Q1089074 http://www.wikidata.org/prop/direct/P21 male

# %% [markdown]
# Apparently there was already some information about Federico Zeri's birth date. Let's analyse it:

# %%
for s,p,o in g.triples((wd.Q1089074, wdt.P569, None )):
    print(o, type(o), o.datatype)
# Out:
# 1921 <class 'rdflib.term.Literal'> http://www.w3.org/2001/XMLSchema#gYear
# 1921-08-12 <class 'rdflib.term.Literal'> http://www.w3.org/2001/XMLSchema#date

# %% [markdown]
# *Apparently* the birth date was added with `XSD.gYear` as datatype, that is, only the year was included.
#
# We can remove the duplicate year by using the method `remove()` which allows to specify all the terms of the pattern that we want to remove. In our case we want to remove one specific triple, hence we specify all the three placeholders in the triple pattern.

# %%
g.remove((wd.Q1089074, wdt.P569, Literal("1921-01-01",datatype=XSD.gYear) ))

# check if it has been deleted
for s,p,o in g.triples((wd.Q1089074, wdt.P569, None )):
        print(s, p, o)
# Out:
# http://www.wikidata.org/entity/Q1089074 http://www.wikidata.org/prop/direct/P569 1921-08-12

# %% [markdown]
# ## 4. Saving and storing RDF data

# %% [markdown]
# The changes that we made to the graphs are saved in an in-memory graph, that is, once the python program stops running the information added/removed get lost. To prevent this, we can save the data in a new file (as a good practise, never write on the original data, you never know!).
#
# First, you need to choose the serialization. As aforementioned we can write RDF data by using several syntaxes (e.g. n3, turtle, XML, nquads). In our case, we select the orginal serialisation of our data, i.e. `nquads`.
#
# Second, you need to select the file where to save data. In our case we dump data in the folder `resource`, and we call our file `artchives_enhanced.nq`.

# %%
g.serialize(destination='artchives_enhanced.nq', format='nquads')
# if run in colab, download from the left sidebar or, run the following:
#from google.colab import files
#files.download('artchives_enhanced.nq')

# %% [markdown]
# Useful links:
#
#  * [RDFlib official documentation](https://rdflib.readthedocs.io/en/stable/gettingstarted.html)
#  * [Youtube series of tutorial on working on RDF with python](https://www.youtube.com/watch?v=sCU214rbRZ0) Pay attention! in this tutorial the speaker is working with **only one graph**, hence he uses the RDFlib class `Graph()`, while we worked on several graphs included in one file, hence we used the class `ConjunctiveGraph()`. It's worth to notice that when you work on a single graph you have more methods then when working on multiple graphs (e.g. `Graph()` allows you to iterate over subjects, objects, subjects and predicates, predicates and objects, while `ConjunctiveGraph()` allows you to iterate only on `triples()` and `quads()`)
#  * **There is also a Javascript library called [rdflib](https://linkeddata.github.io/rdflib.js/doc/) to handle data client-side (in the browser).** We will not use this in our classes, but you are welcome to explore it for future use and eventually for your project!

# %% [markdown]
# ## Homework
#
# Fill in the [questionnaire](https://forms.gle/uWW3j7sXNZ8WF3B89)
